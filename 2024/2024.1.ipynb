# %% [markdown]
# <a href="https://colab.research.google.com/github/itchy-squid/AdventOfCode/blob/2024-6/2024/2024.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
fread = lambda path: open(path,'r').read()

# %%
#@title Day 1: Historian Histeria
input = [l.split('   ') for l in fread('input.txt').splitlines()]
a = [int(l[0]) for l in input]
b = [int(l[1]) for l in input]
a.sort()
b.sort()
ds = [abs(a[i]-b[i]) for i in range(len(a))]
print(sum(ds))
print(sum([x * b.count(x) for x in a]))
# Out:
# 2430334
# 28786472

# %%
#@title Day 2: Red-Nosed Reports
import math
lines = [[int(i) for i in l.split(' ')] for l in fread('input 2.txt').splitlines()]

part1 = lambda l: all([(0 < (math.copysign(1,l[1] - l[0]) * (l[j] - l[j-1])) < 4) for j in range(1,len(l))])
part2 = lambda l: part1(l) or any([part1(l[0:j]+l[j+1:]) for j in range(len(l))])

print(sum([part1(l) for l in lines]))
print(sum([part2(l) for l in lines]))
# Out:
# 421
# 476

# %%
#@title Day 3: Mull It Over
import re
input = fread('input 3.txt')

muls = r'mul\((?P<x>\d+),(?P<y>\d+)\)'
part1 = lambda l: sum([int(m['x'])*int(m['y']) for m in re.finditer(muls,l)])
part2 = lambda ls: sum([part1(l.split('don\'t()')[0]) for l in ls.split('do()')])

print(part1(input))
print(part2(input))
# Out:
# 196826776
# 106780429

# %%
#@title Day 4-1: Ceres Search
input = fread('input 4.txt').splitlines()

def rotate45(m):
  L = len(m)
  W = len(m[0])
  return [[ m[min(r,L-1)-d][max(0,r-L+1)+d]
      for d in range(min(W,L-abs(r-L+1)))]
      for r in range(L+W-1)]

rotate90 = lambda m: list(zip(*m[::-1]))
xmas = lambda m: sum([''.join(l).count('XMAS') for l in m])

# part 1
acc = (0,input)
[acc := (acc[0]+xmas(acc[1])+xmas(rotate45(acc[1])),rotate90(acc[1])) for i in range(0,4)]
print(acc[0])
# Out:
# 2646

# %%
#@title Day 4-2: Ceres Search
input = fread('input 4.txt').splitlines()

isLeg = lambda s: s in {'MAS','SAM'}
isXmas = lambda m,i,j: isLeg(str(m[i-1][j-1]+m[i][j]+m[i+1][j+1])) and isLeg(str(m[i-1][j+1]+m[i][j]+m[i+1][j-1]))

print(sum([isXmas(input,i,j) for j in range(1,len(input[0])-1) for i in range(1,len(input)-1)]))
# Out:
# 2000

# %%
#@title Day 6: Guard Gallivant
import math

sample='''....#.....
.........#
..........
..#.......
.......#..
..........
.#..^.....
........#.
#.........
......#...'''

DEBUG = False
input = sample if DEBUG else fread('input 6.txt')

map = input.splitlines()
w = len(map[0])
l = len(map)

DS = [(-1,0),(0,1),(1,0),(0,-1)]
WALL = '#'
START = '^'

initialPosition = next(iter([(i,j) for j in range(w) for i in range(l) if map[i][j] == START]))
initialDirection = 0

lookAhead = lambda p,d: (p[0]+d[0],p[1]+d[1])
isValid = lambda p: -1<p[0]<l and -1<p[1]<w

def travel(map, i, j, i_ds, visited=[]):
  while True:
    if (i,j,i_ds) in visited: return None
    visited = visited + [(i,j,i_ds)]
    visiting = lookAhead((i,j),DS[i_ds])
    if not isValid(visiting): break
    if map[visiting[0]][visiting[1]] == WALL: i_ds = (i_ds + 1) % len(DS)
    else: i,j = visiting
  return visited

path = travel(map, *initialPosition, initialDirection)
print(len(set([tuple(p[0:2]) for p in path])))

import itertools

def loopPoints(path):
  for k in range(len(path)):
    i,j,d = path[k]
    ahead = lookAhead((i,j),DS[d])

    if not isValid(ahead): break
    if map[ahead[0]][ahead[1]] == WALL: continue

    m = map[:ahead[0]]+[''.join((map[ahead[0]][0:ahead[1]],WALL,map[ahead[0]][ahead[1]:]))] + map[ahead[0]:]
    rightDirection = (d+1)%len(DS)
    if travel(m,i,j,rightDirection,path[0:k+1]) is None: yield ahead

print(set(loopPoints(path)))
# Out:
# 5329
# {(107, 95), (67, 59), (86, 72), (18, 17), (26, 21), (97, 81), (70, 64), (71, 29), (90, 42), (82, 38), (101, 51), (102, 16), (48, 45), (94, 12), (19, 18), (52, 15), (50, 91), (84, 4), (69, 104), (75, 35), (116, 36), (81, 78), (41, 42), (127, 45), (106, 22), (73, 74), (87, 9), (44, 47), (85, 48), (64, 25), (109, 33), (85, 84), (78, 45), (38, 9), (97, 58), (98, 23), (51, 91), (16, 70), (101, 28), (18, 30), (46, 98), (71, 42), (82, 51), (77, 85), (69, 81), (29, 45), (21, 41), (42, 100), (116, 49), (127, 58), (25, 47), (45, 25), (97, 35), (109, 46), (18, 7), (32, 91), (78, 58), (64, 123), (16, 83), (35, 96), (101, 41), (48, 35), (21, 18), (52, 5), (75, 25), (115, 61), (116, 26), (108, 22), (81, 68), (8, 84), (27, 97), (73, 64), (74, 29), (127, 35), (93, 42), (33, 28), (91, 118), (62, 91), (22, 18), (109, 23), (114, 101), (20, 94), (66, 61), (106, 97), (72, 104), (78, 35), (97, 48), (90, 9), (36, 38), (55, 51), (96, 89), (88, 85), (99, 94), (119, 72), (112, 33), (57, 97), (58, 62), (49, 93), (81, 45), (27, 74), (73, 41), (58, 98), (91, 95), (116, 39), (102, 104), (108, 35), (127, 48), (74, 42), (20, 71), (84, 92), (89, 21), (75, 123), (34, 91), (45, 100), (37, 96), (71, 9), (90, 22), (57, 74), (77, 52), (28, 47), (40, 21), (100, 72), (115, 51), (110, 85), (8, 74), (127, 25), (91, 108), (84, 69), (35, 27), (122, 95), (95, 78), (55, 5), (96, 43), (13, 45), (78, 25), (70, 21), (89, 34), (36, 28), (22, 93), (68, 60), (46, 78), (65, 91), (38, 74), (57, 87), (58, 52), (49, 83), (27, 64), (93, 9), (79, 111), (31, 34), (29, 110), (74, 32), (52, 93), (84, 82), (124, 118), (96, 56), (88, 52), (59, 25), (58, 29), (49, 60), (77, 42), (61, 34), (120, 120), (27, 41), (38, 87), (112, 36), (58, 65), (81, 48), (48, 100), (73, 44), (74, 9), (60, 74), (12, 34), (31, 47), (51, 25), (84, 59), (43, 21), (75, 90), (95, 68), (88, 29), (99, 38), (64, 80), (36, 18), (47, 27), (45, 103), (37, 99), (111, 48), (57, 77), (58, 42), (104, 9), (42, 34), (27, 54), (18, 85), (39, 28), (63, 93), (91, 75), (82, 106), (84, 36), (29, 100), (103, 49), (41, 74), (60, 87), (118, 28), (84, 72), (43, 34), (89, 1), (88, 42), (37, 76), (97, 90), (58, 19), (50, 15), (68, 63), (69, 28), (61, 24), (67, 104), (26, 66), (18, 62), (71, 74), (91, 52), (42, 47), (62, 25), (106, 31), (52, 60), (126, 9), (83, 84), (29, 113), (103, 62), (96, 23), (88, 19), (34, 48), (52, 96), (56, 66), (77, 9), (49, 27), (68, 40), (120, 87), (18, 39), (78, 90), (36, 93), (82, 60), (15, 70), (110, 42), (42, 24), (27, 44), (39, 18), (71, 87), (115, 93), (95, 35), (45, 34), (118, 18), (64, 47), (109, 55), (37, 66), (32, 100), (97, 80), (58, 9), (49, 40), (50, 5), (101, 50), (18, 52), (63, 60), (75, 34), (95, 12), (41, 41), (106, 21), (53, 15), (104, 97), (88, 9), (34, 38), (65, 25), (56, 56), (49, 17), (80, 4), (86, 84), (97, 93), (43, 122), (71, 41), (17, 70), (50, 18), (82, 50), (42, 14), (101, 63), (100, 104), (75, 47), (103, 29), (81, 90), (41, 54), (53, 28), (39, 93), (45, 24), (37, 20), (22, 40), (109, 45), (34, 51), (37, 56), (38, 21), (79, 22), (97, 70), (70, 53), (89, 66), (110, 9), (101, 40), (67, 84), (18, 42), (5, 72), (82, 63), (48, 70), (106, 11), (109, 22), (127, 70), (34, 28), (25, 59), (20, 93), (66, 60), (37, 33), (78, 34), (89, 43), (68, 20), (67, 61), (107, 97), (99, 93), (18, 19), (119, 71), (70, 66), (71, 31), (63, 27), (101, 53), (48, 47), (46, 123), (52, 17), (44, 13), (63, 63), (50, 93), (69, 106), (75, 37), (116, 38), (21, 66), (41, 44), (33, 40), (74, 41), (85, 50), (64, 27), (109, 35), (78, 47), (51, 93), (89, 56), (101, 30), (40, 20), (46, 100), (71, 44), (63, 40), (58, 74), (75, 14), (115, 50), (61, 79), (40, 56), (127, 24), (60, 34), (106, 1), (30, 91), (105, 42), (91, 107), (22, 7), (109, 12), (20, 83), (37, 23), (70, 20), (84, 104), (43, 66), (36, 27), (55, 40), (88, 74), (111, 57), (77, 64), (48, 37), (57, 122), (58, 87), (110, 97), (116, 28), (108, 24), (8, 86), (73, 66), (66, 27), (84, 81), (109, 25), (122, 107), (55, 17), (114, 103), (20, 96), (86, 41), (59, 24), (72, 106 ...
